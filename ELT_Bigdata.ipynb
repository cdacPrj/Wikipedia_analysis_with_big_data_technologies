# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.4)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %%
import pyspark as sp

sc = sp.SparkContext.getOrCreate()
print(sc)
print(sc.version)
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>
# 3.5.4

# %%
#import SparkSeccion pyspark.sql
from pyspark.sql import SparkSession

#Create my_spark
spark = SparkSession.builder.getOrCreate()

#print my_spark
print(spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7db2fc523590>

# %%
import pandas as pd
import numpy as np

# Create pd_temp
pd_temp = pd.DataFrame(np.random.random(10))

# Create spark_temp from pd_temp
spark_temp = spark.createDataFrame(pd_temp)

# Examine the tables in the catalog
print(spark.catalog.listTables())

# Add spark_temp to the catalog
spark_temp.createOrReplaceTempView("temp")

# Examine the tables in the catalog again
print(spark.catalog.listTables())
# Out:
# []
# [Table(name='temp', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
otherPeopleRDD = sc.parallelize(data)
otherPeople = spark.read.json(otherPeopleRDD)
otherPeople.show()
# Out:
# +---------------+
# |_corrupt_record|
# +---------------+
# |            tfa|
# |       mostread|
# |           news|
# |      onthisday|
# +---------------+

# %%
otherPeople.collect()
# Out:
# [Row(_corrupt_record='tfa'),
#  Row(_corrupt_record='mostread'),
#  Row(_corrupt_record='news'),
#  Row(_corrupt_record='onthisday')]

# %%
import datetime
import requests
import json
from pyspark.sql import SparkSession

# Initialize Spark Session
spark = SparkSession.builder.appName("WikiAPI").getOrCreate()

# %%
# Get today's date
today = datetime.datetime.now()
date = today.strftime('%Y/%m/%d')

# Wikipedia API URL
url = f'https://api.wikimedia.org/feed/v1/wikipedia/en/featured/{date}'

# Headers (Replace with actual access token)
headers = headers

# Fetch API Response
response = requests.get(url, headers=headers)

# Save JSON Response as a File
json_filename = "wikipedia_featured.json"
with open(json_filename, "w") as json_file:
    json.dump(response.json(), json_file, indent=4)

# %%
# Read JSON into PySpark DataFrame
df = spark.read.option("multiline", "true").json(json_filename)

# Show Schema and Data
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- artist: struct (nullable = true)
#  |    |    |-- html: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |-- credit: struct (nullable = true)
#  |    |    |-- html: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |-- description: struct (nullable = true)
#  |    |    |-- html: string (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |-- file_page: string (nullable = true)
#  |    |-- image: struct (nullable = true)
#  |    |    |-- height: long (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- width: long (nullable = true)
#  |    |-- license: struct (nullable = true)
#  |    |    |-- code: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- structured: struct (nullable = true)
#  |    |    |-- captions: struct (nullable = true)
#  |    |    |    |-- af: string (nullable = true)
#  |    |    |    |-- de: string (nullable = true)
#  |    |    |    |-- el: string (nullable = true)
#  |    |    |    |-- en: string (nullable = true)
#  |    |    |    |-- es: string (nullable = true)
#  |    |    |    |-- fi: string (nullable = true)
#  |    |    |    |-- fr: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- it: string (nullable = true)
#  |    |    |    |-- nl: string (nullable = true)
#  |    |    |    |-- pl: string (nullable = true)
#  |    |    |    |-- uk: string (nullable = true)
#  |    |    |    |-- vi: string (nullable = true)
#  |    |-- thumbnail: struct (nullable = true)
#  |    |    |-- height: long (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- width: long (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- wb_entity_id: string (nullable = true)
#  |-- mostread: struct (nullable = true)
#  |    |-- articles: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- content_urls: struct (nullable = true)
#  |    |    |    |    |-- desktop: struct (nullable = true)
#  |    |    |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |    |    |-- page: string (nullable = true)
#  |    |    |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |    |    |-- talk: string (nullable = true)
#  |    |    |    |    |-- mobile: struct (nullable = true)
#  |    |    |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |    |    |-- page: string (nullable = true)
#  |    |    |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |    |    |-- talk: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- description_source: string (nullable = true)
#  |    |    |    |-- dir: string (nullable = true)
#  |    |    |    |-- displaytitle: string (nullable = true)
#  |    |    |    |-- extract: string (nullable = true)
#  |    |    |    |-- extract_html: string (nullable = true)
#  |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |-- namespace: struct (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- normalizedtitle: string (nullable = true)
#  |    |    |    |-- originalimage: struct (nullable = true)
#  |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |-- source: string (nullable = true)
#  |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- pageid: long (nullable = true)
#  |    |    |    |-- rank: long (nullable = true)
#  |    |    |    |-- revision: string (nullable = true)
#  |    |    |    |-- thumbnail: struct (nullable = true)
#  |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |-- source: string (nullable = true)
#  |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- tid: string (nullable = true)
#  |    |    |    |-- timestamp: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- titles: struct (nullable = true)
#  |    |    |    |    |-- canonical: string (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- normalized: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- view_history: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- date: string (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- wikibase_item: string (nullable = true)
#  |    |-- date: string (nullable = true)
#  |-- news: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- links: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- content_urls: struct (nullable = true)
#  |    |    |    |    |    |-- desktop: struct (nullable = true)
#  |    |    |    |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |    |    |    |-- page: string (nullable = true)
#  |    |    |    |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |    |    |    |-- talk: string (nullable = true)
#  |    |    |    |    |    |-- mobile: struct (nullable = true)
#  |    |    |    |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |    |    |    |-- page: string (nullable = true)
#  |    |    |    |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |    |    |    |-- talk: string (nullable = true)
#  |    |    |    |    |-- coordinates: struct (nullable = true)
#  |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |-- lon: double (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- description_source: string (nullable = true)
#  |    |    |    |    |-- dir: string (nullable = true)
#  |    |    |    |    |-- displaytitle: string (nullable = true)
#  |    |    |    |    |-- extract: string (nullable = true)
#  |    |    |    |    |-- extract_html: string (nullable = true)
#  |    |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |    |-- namespace: struct (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- normalizedtitle: string (nullable = true)
#  |    |    |    |    |-- originalimage: struct (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- source: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- pageid: long (nullable = true)
#  |    |    |    |    |-- revision: string (nullable = true)
#  |    |    |    |    |-- thumbnail: struct (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- source: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- tid: string (nullable = true)
#  |    |    |    |    |-- timestamp: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- titles: struct (nullable = true)
#  |    |    |    |    |    |-- canonical: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- normalized: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- wikibase_item: string (nullable = true)
#  |    |    |-- story: string (nullable = true)
#  |-- onthisday: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- pages: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- content_urls: struct (nullable = true)
#  |    |    |    |    |    |-- desktop: struct (nullable = true)
#  |    |    |    |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |    |    |    |-- page: string (nullable = true)
#  |    |    |    |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |    |    |    |-- talk: string (nullable = true)
#  |    |    |    |    |    |-- mobile: struct (nullable = true)
#  |    |    |    |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |    |    |    |-- page: string (nullable = true)
#  |    |    |    |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |    |    |    |-- talk: string (nullable = true)
#  |    |    |    |    |-- coordinates: struct (nullable = true)
#  |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |-- lon: double (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- description_source: string (nullable = true)
#  |    |    |    |    |-- dir: string (nullable = true)
#  |    |    |    |    |-- displaytitle: string (nullable = true)
#  |    |    |    |    |-- extract: string (nullable = true)
#  |    |    |    |    |-- extract_html: string (nullable = true)
#  |    |    |    |    |-- lang: string (nullable = true)
#  |    |    |    |    |-- namespace: struct (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- normalizedtitle: string (nullable = true)
#  |    |    |    |    |-- originalimage: struct (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- source: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- pageid: long (nullable = true)
#  |    |    |    |    |-- revision: string (nullable = true)
#  |    |    |    |    |-- thumbnail: struct (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- source: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- tid: string (nullable = true)
#  |    |    |    |    |-- timestamp: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- titles: struct (nullable = true)
#  |    |    |    |    |    |-- canonical: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- normalized: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- wikibase_item: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- year: long (nullable = true)
#  |-- tfa: struct (nullable = true)
#  |    |-- content_urls: struct (nullable = true)
#  |    |    |-- desktop: struct (nullable = true)
#  |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |-- page: string (nullable = true)
#  |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |-- talk: string (nullable = true)
#  |    |    |-- mobile: struct (nullable = true)
#  |    |    |    |-- edit: string (nullable = true)
#  |    |    |    |-- page: string (nullable = true)
#  |    |    |    |-- revisions: string (nullable = true)
#  |    |    |    |-- talk: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- description_source: string (nullable = true)
#  |    |-- dir: string (nullable = true)
#  |    |-- displaytitle: string (nullable = true)
#  |    |-- extract: string (nullable = true)
#  |    |-- extract_html: string (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- namespace: struct (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |-- normalizedtitle: string (nullable = true)
#  |    |-- originalimage: struct (nullable = true)
#  |    |    |-- height: long (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- width: long (nullable = true)
#  |    |-- pageid: long (nullable = true)
#  |    |-- revision: string (nullable = true)
#  |    |-- thumbnail: struct (nullable = true)
#  |    |    |-- height: long (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |    |    |-- width: long (nullable = true)
#  |    |-- tid: string (nullable = true)
#  |    |-- timestamp: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- titles: struct (nullable = true)
#  |    |    |-- canonical: string (nullable = true)
#  |    |    |-- display: string (nullable = true)
#  |    |    |-- normalized: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- wikibase_item: string (nullable = true)
#
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |image                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |mostread                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |{{<bdi><a href="https://www.wikidata.org/wiki/Q34788025" class="extiw" title="d:Q34788025"><span title="German photographer and mathematician">Dietmar Rabich</span></a>\n</bdi>, Dietmar Rabich}, {<span class="int-own-work" lang="en">Own work</span>, Own work}, {Elephant (<a rel="mw:WikiLink" href="./Category:Loxodonta_africana" title="Category:Loxodonta africana">Loxodonta africana</a>) in <a rel="mw:WikiLink" href="./Category:Kruger_National_Park" title="Category:Kruger National Park">Kruger National Park</a>, Mpumalanga, South Africa, en, Elephant (Loxodonta africana) in Kruger National Park, Mpumalanga, South Africa}, https://commons.wikimedia.org/wiki/File:Kruger_National_Park_(ZA),_Elefant_--_2024_--_0649.jpg, {4276, https://upload.wikimedia.org/wikipedia/commons/8/88/Kruger_National_Park_%28ZA%29%2C_Elefant_--_2024_--_0649.jpg, 6414}, {cc-by-sa-4.0, CC BY-SA 4.0, https://creativecommons.org/licenses/by-sa/4.0}, {{Olifant in Krugerwildtuin, Mpumalanga, Suid-Afrika (2024), Elefanten im trockenen Flussbett des Mutlum
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
# Explode the `articles` array inside `mostread`
from pyspark.sql.functions import explode, col

df_articles = df.select(explode(col("mostread.articles")).alias("article"))

# Select Required Fields
df_flat = df_articles.select(
    col("article.title").alias("Title"),
    col("article.description").alias("Description"),
    col("article.extract").alias("Extract"),
    col("article.content_urls.desktop.page").alias("URL"),
    col("article.views").alias("Views"),
    col("article.timestamp").alias("Timestamp")
)

# Show Results
df_flat.show(truncate=False)
# Out:
# +--------------------------------+------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------+------+--------------------+
# |Title                           |Description                                                             |Extract                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |URL                                                             |Views |Timestamp           |
# +--------------------------------+------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------+------+--------------------+
# |Kim_Sae-ron                     |South Korean actress (2000–2025)                                        |Kim Sae-ron was a South Korean actress. Kim started her career in 2001, debuting as a child model. At the age of nine, she transitioned into acting and became popular through the films A Brand New Life (2009) and The Man From Nowhere (2010).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |https://en.wikipedia.org/wiki/Kim_Sae-ron                       |462827|2025-02-18T16:10:28Z|
# |Chhaava                         |2025 Hindi film by Laxman Utekar                                        |Chhaava is a 2025 Indian Hindi-language epic historical action film based on the life of Chatrapati Sambhaji Maharaj, the second ruler of the Maratha Confederacy, played by Vicky Kaushal. It is an adaptation of the Marathi novel Chhava by Shivaji Sawant. Directed by Laxman Utekar and produced by Dinesh Vijan under Maddock Films, the film also stars Rashmika Mandanna and Akshaye Khanna.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |https://en.wikipedia.org/wiki/Chhaava                           |409516|2025-02-18T15:43:51Z|
# |The_White_Lotus_season_3        |Season of television series                                             |The third season of The White Lotus, an American satirical comedy-drama anthology television series created, written, and directed by Mike White, premiered on HBO on February 16, 2025. The season was greenlit on November 18, 2022, and was filmed in Bangkok, Phuket, and Ko Samui from February to August 2024.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |https://en.wikipedia.org/wiki/The_White_Lotus_season_3          |385238|2025-02-18T13:23:16Z|
# |Sabrina_Carpenter               |American singer and actress (born 1999)                                 |Sabrina Annlynn Carpenter is an American singer, songwriter, and actress. She gained prominence starring on the Disney Channel series Girl Meets World (2014–2017), and signed with the Disney-owned Hollywood Records. She released her debut single, "Can't Blame a Girl for Trying" in 2014, followed by the studio albums Eyes Wide Open (2015), Evolution (2016), Singular: Act I (2018), and Singular: Act II (2019).                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |https://en.wikipedia.org/wiki/Sabrina_Carpenter                 |368441|2025-02-18T08:46:37Z|
# |Brittany_Howard                 |American singer (born 1988)                                             |Brittany Amber Howard is an American musician from Athens, Alabama. She rose to prominence in the early 2010s as the lead vocalist, rhythm guitarist, and primary songwriter of Alabama Shakes. Her work with Alabama Shakes garnered her four Grammy Awards from nine nominations. Later in the decade, Howard played bass in the side project Thunderbitch and both acoustic guitar and double bass for the trio Bermuda Triangle.                                                                                                                                                                                                                                                                                                                                                                                                                                                             |https://en.wikipedia.org/wiki/Brittany_Howard                   |349714|2025-02-17T22:23:23Z|
# |Null                            |Topics referred to by the same term                                     |Null may refer to:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |https://en.wikipedia.org/wiki/Null                              |291587|2025-02-07T21:42:17Z|
# |Sambhaji                        |Second Chhatrapati of the Marathas                                      |Sambhaji, also known as Shambhuraje, was the second Chhatrapati of the Maratha Empire, ruling from 1681 to 1689. He was the eldest son of Shivaji, the founder of the Maratha kingdom.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------+------+--------------------+
# only showing top 20 rows

# %%
df_images = df.select(
    col("image.title").alias("Image_Title"),
    col("image.file_page").alias("File_Page"),
    col("image.image.source").alias("Image_URL"),
    col("image.license.url").alias("License_URL")
)

df_images.show(truncate=False)
# Out:
# +-----------------------------------------------------------+----------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+----------------------------------------------+
# |Image_Title                                                |File_Page                                                                                     |Image_URL                                                                                                       |License_URL                                   |
# +-----------------------------------------------------------+----------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+----------------------------------------------+
# |File:Kruger National Park (ZA), Elefant -- 2024 -- 0649.jpg|https://commons.wikimedia.org/wiki/File:Kruger_National_Park_(ZA),_Elefant_--_2024_--_0649.jpg|https://upload.wikimedia.org/wikipedia/commons/8/88/Kruger_National_Park_%28ZA%29%2C_Elefant_--_2024_--_0649.jpg|https://creativecommons.org/licenses/by-sa/4.0|
# +-----------------------------------------------------------+----------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------+----------------------------------------------+

# %% [markdown]
# #PreProcessing

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import col, when, count
from pyspark.sql import SparkSession

# Assuming you already have SparkSession initialized
spark = SparkSession.builder.getOrCreate()

# Check for null values in df_articles
df_flat.select([count(when(col(c).isNull(), c)).alias(c) for c in df_flat.columns]).show()

# Check for null values in df_images
df_images.select([count(when(col(c).isNull(), c)).alias(c) for c in df_images.columns]).show()
# Out:
# +-----+-----------+-------+---+-----+---------+
# |Title|Description|Extract|URL|Views|Timestamp|
# +-----+-----------+-------+---+-----+---------+
# |    0|          0|      0|  0|    0|        0|
# +-----+-----------+-------+---+-----+---------+
#
# +-----------+---------+---------+-----------+
# |Image_Title|File_Page|Image_URL|License_URL|
# +-----------+---------+---------+-----------+
# |          0|        0|        0|          0|
# +-----------+---------+---------+-----------+

# %%
# Remove duplicates from df_articles and df_images
df_flat = df_flat.dropDuplicates(['Title'])
df_images = df_images.dropDuplicates(['Image_Title'])

# %%
print(df_flat.columns)
print(df_images.columns)
# Out:
# ['Title', 'Description', 'Extract', 'URL', 'Views', 'Timestamp']
# ['Image_Title', 'File_Page', 'Image_URL', 'License_URL']

# %%
#Trimming whitespaces
from pyspark.sql.functions import trim

df_flat = df_flat.withColumn("Title", trim(col("Title"))) \
                         .withColumn("Description", trim(col("Description"))) \
                         .withColumn("Extract", trim(col("Extract"))) \
                         .withColumn("URL", trim(col("URL")))

df_images = df_images.withColumn("Image_Title", trim(col("Image_Title"))) \
                     .withColumn("File_Page", trim(col("File_Page"))) \
                     .withColumn("Image_URL", trim(col("Image_URL"))) \
                     .withColumn("License_URL", trim(col("License_URL")))

# %% [markdown]
# #Feature Engineering

# %%
from pyspark.sql.functions import when, length

# Extract Date from Timestamp
df_flat = df_flat.withColumn("Date", col("Timestamp").cast("date"))

# %%
# Categorize articles based on Views
df_flat = df_flat.withColumn(
    "Popularity",
    when(col("Views") < 10000, "Low")
    .when((col("Views") >= 10000) & (col("Views") < 50000), "Medium")
    .otherwise("High")
)

# %%
df_flat.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+------+--------------------+----------+----------+
# |               Title|         Description|             Extract|                 URL| Views|           Timestamp|      Date|Popularity|
# +--------------------+--------------------+--------------------+--------------------+------+--------------------+----------+----------+
# |2025_4_Nations_Fa...|International men...|The 2025 4 Nation...|https://en.wikipe...|130851|2025-02-18T15:12:40Z|2025-02-18|      High|
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |https://en.wikipedia.org/wiki/Jane_Curtin                       |166318|2025-02-14T23:59:04Z|2025-02-14|High      |NULL     |NULL     |NULL       |
# |Jeff_Baena                      |American screenwriter and film director (1977–2025)           |Jeffrey Lance Baena was an American screenwriter and film director. Baena began his career as a screenwriter, co-writing the 2004 comedy film I Heart Huckabees and, around the same time, seeing his script for Life After Beth enter production before being shelved. Baena, as an independent filmmaker, then expanded to directing and filmed Life After Beth as his directorial debut, starring Aubrey Plaza and released in 2014. Working with producer Liz Destro, and reuniting with Plaza as well as an expanding group of frequent collaborators, Baena was then writer-director for Joshy (2016) and The Little Hours (2017), which both became critically acclaimed and found a cult audience.                                                                                                                                                                                       |https://en.wikipedia.org/wiki/Jeff_Baena                        |125149|2025-02-18T12:16:41Z|2025-02-18|High      |NULL     |NULL     |NULL       |
# |John_Belushi                    |American comedian and actor (1949–1982)                       |John Adam Belushi was an American comedian, actor, and musician. He was one of seven Saturday Night Live cast members of the first season. Along with Chevy Chase, he was arguably the most popular member of the Saturday Night Live ensemble. Belushi had a partnership with Dan Aykroyd. They had first met while at Chicago's the Second City comedy club, remaining together as cast members on the inaugural season of the television show Saturday Night Live.                                                                                                                                                                                                                                                                                                                                                                                                                            |https://en.wikipedia.org/wiki/John_Belushi                      |119465|2025-02-11T05:23:50Z|2025-02-11|High      |NULL     |NULL     |NULL       |
# +--------------------------------+--------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------+------+--------------------+----------+----------+---------+---------+-----------+
# only showing top 20 rows

# %% [markdown]
# #Analytics by loading Data into Spark Tables

# %%
# Create Spark SQL tables for both dataframes
df_flat.createOrReplaceTempView("wikipedia_articles")
df_images.createOrReplaceTempView("wikipedia_images")

# %%
#1) Find the Most Popular Articles
spark.sql("""
    SELECT Title, Views, Popularity, URL
    FROM wikipedia_articles
    ORDER BY Views DESC
    LIMIT 10
""").show(truncate=False)
# Out:
# +--------------------------------+------+----------+----------------------------------------------------------------+
# |Title                           |Views |Popularity|URL                                                             |
# +--------------------------------+------+----------+----------------------------------------------------------------+
# |Kim_Sae-ron                     |462827|High      |https://en.wikipedia.org/wiki/Kim_Sae-ron                       |
# |Chhaava                         |409516|High      |https://en.wikipedia.org/wiki/Chhaava                           |
# |The_White_Lotus_season_3        |385238|High      |https://en.wikipedia.org/wiki/The_White_Lotus_season_3          |
# |Sabrina_Carpenter               |368441|High      |https://en.wikipedia.org/wiki/Sabrina_Carpenter                 |
# |Brittany_Howard                 |349714|High      |https://en.wikipedia.org/wiki/Brittany_Howard                   |
# |Null                            |291587|High      |https://en.wikipedia.org/wiki/Null                              |
# |Sambhaji                        |279748|High      |https://en.wikipedia.org/wiki/Sambhaji                          |
# |Captain_America:_Brave_New_World|267954|High      |https://en.wikipedia.org/wiki/Captain_America%3A_Brave_New_World|
# |Lorne_Michaels                  |248756|High      |https://en.wikipedia.org/wiki/Lorne_Michaels                    |
# |Belle_Gibson                    |239338|High      |https://en.wikipedia.org/wiki/Belle_Gibson                      |
# +--------------------------------+------+----------+----------------------------------------------------------------+

# %%
#2) Count of Articles by Popularity Category
spark.sql("""
    SELECT Popularity, COUNT(*) AS Article_Count
    FROM wikipedia_articles
    GROUP BY Popularity
    ORDER BY Article_Count DESC
""").show()
# Out:
# +----------+-------------+
# |Popularity|Article_Count|
# +----------+-------------+
# |      High|           47|
# +----------+-------------+
